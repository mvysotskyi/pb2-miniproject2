# %% [markdown]
# ### Побудова дороги через екосистему найменше їй зашкодивши

# %% [markdown]
# #### Навіщо взагалі це робити?

# %% [markdown]
# На наступних графіках ви побачите трішки статистики

# %%
# !pip install seaborn
# !pip install matplotlib
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      -------------------------------------- 293.3/293.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sasha\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\sasha\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
years = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
occasions = [1016,1236,2088,7704,5948,5405,5558,8898,8298,14379]
plt.plot(years, occasions, color = 'green')
plt.title('Кількість збитих тварин кожного року у Великій Британії', fontsize=14, fontweight='bold')

plt.show()

# %%
countries = ["Бельгія(1995)", "Іспанія(1996)"]
occas = [4000000,10000000]
# plt.bar(countries, occas, color='C4')
sns.set(style="whitegrid", palette="pastel")
ax = sns.barplot(x=countries, y=occas)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'), (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha = 'center', va = 'bottom', xytext = (0, 5), textcoords = 'offset points', fontsize=8)
    
plt.title('Статистика смертності диких тварин на дорогах різних країн', fontsize=14, fontweight='bold')
colors = ['#ADD8E6', '#bebada', '#B0E0E6']
for patch, color in zip(ax.patches, colors):
    patch.set_facecolor(color)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
categories = ['США', 'Іспанія', 'Бельгія', 'Фінляндія']
values = [365, 10, 4, 6.5]
sns.set(style="whitegrid", palette="pastel")
ax = sns.barplot(x=categories, y=values)
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'), (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha = 'center', va = 'bottom', xytext = (0, 5), textcoords = 'offset points', fontsize=8)
    
plt.title('Статистика смертності диких тварин на дорогах (в мільйонах)', fontsize=14, fontweight='bold')
colors = ['#ADD8E6', '#bebada', '#B0E0E6']
for patch, color in zip(ax.patches, colors):
    patch.set_facecolor(color)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
categories = ['Швеція', 'Велика Британія', 'Бельгія', 'Данія', 'Нідерланди']
values = [8.5, 4, 4, 3.7, 2]

sns.set(style="whitegrid", palette="pastel")

ax = sns.barplot(x=categories, y=values)

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'), (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha = 'center', va = 'bottom', xytext = (0, 5), textcoords = 'offset points', fontsize=8)

plt.title('Смертність птахів протягом року (в мільйонах)', fontsize=14, fontweight='bold')

colors = ['#8dd3c7', '#bebada', '#fb8072', '#FFC0CB', '#D8BFD8']
for patch, color in zip(ax.patches, colors):
    patch.set_facecolor(color)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
categories = ['Данія', 'Нідерланди', 'Швеція']
values = [1.5, 0.5, 0.2]

sns.set(style="whitegrid", palette="pastel")

ax = sns.barplot(x=categories, y=values)

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'), (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha = 'center', va = 'bottom', xytext = (0, 5), textcoords = 'offset points', fontsize=9)

plt.title('Смертність ссавців великого та середнього розміру на дорогах (в мільйонах)', fontsize=9, fontweight='bold')

colors = ['#8dd3c7', '#bebada', '#fb8072']
for patch, color in zip(ax.patches, colors):
    patch.set_facecolor(color)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
categories = ['Австралія', 'Данія']
values = [5, 3]

sns.set(style="whitegrid", palette="pastel")

ax = sns.barplot(x=categories, y=values)

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha = 'center', va = 'bottom', xytext = (0, 5), textcoords = 'offset points', fontsize=9)

plt.title('Смертність амфібій на дорогах (в мільйонах)', fontsize=12, fontweight='bold')

colors = ['#98FB98', '#AFEEEE']
for patch, color in zip(ax.patches, colors):
    patch.set_facecolor(color)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %% [markdown]
# Легко бачити, що питання смертності тварин на автодорогах активно досліджується і ця проблема існує. Також, підсумувавши, диких тварин вмирає дуже багато, тому потрібен спосіб, щоб захистити їх від смерті. Особливо це стосується тварин, які занесені в червону книгу, провівши транспортний шлях необережно, можна призвести до вимирання цілої популяції вже й так вимираючого виду. Ми з командою дійшли висновку, що правильне прокладання автодоріг є дуже необхідним в нас час. Розглядаючи цю проблему ми вирішили скористатись бібліотекою Python NEAT(NeuroEvolution of Augmenting Topologies), оскільки вона довзоляє швидко прокласти шлях, у абсолютно різноманітних випадках, використовуючи для цього генетичний алгоритм, і може бути контрольованою залежно від будь-яких вимог.

# %% [markdown]
# #### Інші рішення

# %% [markdown]
# Одним з можливих рішень є побудова графу і знаходження найоптимальнішого шляху, але цей спосіб занадто ресурснозатратний (враховуючи те, що в графі може бути більше одного мільйона вершин), а також менш контрольованих в різних випадках.

# %% [markdown]
# #### Наші критерії оцінки якості побудованого шляху:

# %% [markdown]
# *якісь оцінки*.

# %% [markdown]
# ### Використання NEAT для побудови шляху через випадкову екосистему

# %% [markdown]
# ### Інсталяція необхідних бібліотек
#
# У нашому проекті ми використовуємо бібліотеки:
# - neat (https://neat-python.readthedocs.io/en/latest/) - для генетичного алгоритму(основна бібліотека в нашому проєкті)
# - pygame (https://www.pygame.org/docs/) - для візуалізації результатів
# - perlin_noise (https://pypi.org/project/perlin-noise/) - для генерації нашого ландшафту

# %%
import math
import random

from functools import cache
from collections import namedtuple

import neat
import pygame

from perlin_noise import PerlinNoise
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.10.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### Створюємо серидовище
#
# Наше серидовище - це ліс у якому живе багато травин.

# %%
"""
file: forest.py
"""

class ForestMap:
    Rect = namedtuple("Rect", ["x", "y", "width", "height", "center"])
    def __init__(self, num_organisms: int = 10, screen_width: int = 800, screen_height: int = 600):
        self.num_organisms = num_organisms
        self.screen_width = screen_width
        self.screen_height = screen_height

        self.screen = None
        self._pygame_init()

        self.organisms = list()
        self.picture = None
        self.road = list()

    def _pygame_init(self):
        pygame.init()
        self.screen = pygame.display.set_mode((self.screen_width, self.screen_height))
        pygame.display.set_caption("Random Forest Map Generator")

    def generate_map(self):
        """
        Generate a random forest.
        """
        noise = PerlinNoise(octaves=6, seed=random.randint(0, 100000))
        xpix, ypix = self.screen_width, self.screen_height
        pic = [[noise([i/xpix, j/ypix]) for j in range(xpix)] for i in range(ypix)]

        self.picture = pic

    def generate_organisms(self):
        """
        Generate organisms on the map.
        """
        def make_tree(x, y, size):
            tree_x, tree_y = x, y
            tree_rect = pygame.Rect(tree_x - size // 2, tree_y - size // 2, size, size)

            tree_center_x, tree_center_y = tree_rect.center
            tree_rect = self.Rect(tree_center_x, tree_center_y, size, size, (tree_x, tree_y))
            self.organisms.append((tree_rect, (random.randint(200, 255), 0, 0)))

        margin = 10
        for i in range(0, len(self.picture) - margin, margin):
            for j in range(0, len(self.picture[i]) - margin, margin):
                chance = random.random()
                if self.picture[i][j]>=0.2 and chance < 0.3:
                    make_tree(j, i, 4)
                elif self.picture[i][j]>=0.09 and chance < 0.2:
                    make_tree(j, i, 3)
                elif self.picture[i][j]>=0.009 and chance < 0.1:
                    make_tree(j, i, 3)
                elif self.picture[i][j]>=-0.3 and chance < 0.05:
                    make_tree(j, i, 3)

        self.organisms = tuple(self.organisms)

    def _update_picture(self):
        """
        Update the picture of the forest.
        """
        screen = self.screen
        for i, row in enumerate(self.picture):
            for j, column in enumerate(row):
                if column>=0.2:
                    # There will be generated animals
                    pygame.draw.rect(screen, (80, 80, 80), pygame.Rect(j, i, 1, 1))             
                elif column>=0.09:
                    pygame.draw.rect(screen, (30, 90, 30), pygame.Rect(j, i, 1, 1))
                elif column >=0.009:
                    pygame.draw.rect(screen, (10, 100, 10), pygame.Rect(j, i, 1, 1))
                elif column >=0.002:
                    pygame.draw.rect(screen, (100, 150, 0), pygame.Rect(j, i, 1, 1))
                elif column >=-0.06:
                    pygame.draw.rect(screen, (30, 190, 0), pygame.Rect(j, i, 1, 1))
                elif column >=-0.02:
                    pygame.draw.rect(screen, (40, 200, 0), pygame.Rect(j, i, 1, 1))
                elif column >=-0.3:
                    pygame.draw.rect(screen, (10, 210, 0), pygame.Rect(j, i, 1, 1))
                elif column >=-0.8 and column <-0.3:
                    pygame.draw.rect(screen, (0, 0, 200), pygame.Rect(j, i, 1, 1))

    def _update_organisms(self):
        """
        Update the organisms positions in the forest.
        """
        for tree, color in self.organisms:
            pygame.draw.rect(self.screen, color, (tree.x, tree.y, tree.width, tree.height))

    def _update_path(self):
        """
        Draw a path on the screen.
        """
        assert self.screen is not None, "Must call pygame_init() before drawing a path."

        for i in range(len(self.road) - 1):
            pygame.draw.line(self.screen, (255, 255, 255), self.road[i], self.road[i + 1], 2)

    def run(self):
        """
        Run the simulation.
        """
        assert self.screen is not None, "Must call pygame_init() before running the simulation."
        pygame.display.update()

        # Wait for the user to close the window
        running = True
        while running:
            self.screen.fill((0, 0, 0))

            self._update_picture()
            self._update_organisms()
            self._update_path()

            pygame.time.delay(1000)
            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    running = False

        pygame.quit()

# %% [markdown]
# ### Імплементація алгоритму для побудови дороги

# %% [markdown]
# #### Імплементація батьківського класу

# %%
"""
file: builder.py
"""

class NeatForestRoadBuilder:
    """
    A class that uses NEAT to build a road through a forest.
    """
    def __init__(self, forest_map: ForestMap, num_generations: int = 100, config_path: str = "config-feedforward.txt"):
        self.forest_map = forest_map

        self.forest_organisms: list = forest_map.organisms
        self.screen_width = forest_map.screen_width
        self.screen_height = forest_map.screen_height

        self.road_smoothness = 250
        self.winner = None

        self.num_generations = num_generations
        self.config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                                  neat.DefaultSpeciesSet, neat.DefaultStagnation,
                                  config_path)

    def _build_path(self, net):
        ...

    @staticmethod
    def distance(point1, point2):
        """
        Calculate the distance between two points.
        """
        return math.sqrt((point1[0] - point2[0]) ** 2 + (point1[1] - point2[1]) **2)

    @staticmethod
    @cache
    def nearest_organism_cached(point, organisms, n_first=5):
        """
        Find the nearest organism to a point.
        """
        return sorted(organisms, key=lambda x: __class__.distance(x[0].center, point))[:n_first]

    def is_valid(self, point):
        """
        Check if a point is valid.
        """
        if point[0] < 0 or point[1] < 0 \
            or point[0] >= self.screen_width or point[1] >= self.screen_height:
            return False

        return True

    def eval_genome(self, genome, config):
        """
        Evaluate the fitness of a genome.
        """
        ...

    def eval_genomes(self, genomes, config):
        """
        Evaluate the fitness of a list of genomes.
        """
        for _, genome in genomes:
            genome.fitness = self.eval_genome(genome, config)

    def _find_winner(self):
        pop = neat.Population(self.config)
        winner = pop.run(self.eval_genomes, self.num_generations)
        return winner

    def build(self):
        """
        Build a road through the forest.
        """
        self.winner = self._find_winner() if self.winner is None else self.winner
        net = neat.nn.FeedForwardNetwork.create(self.winner, self.config)

        self.forest_map.road = self._build_path(net)

# %% [markdown]
# #### Дочірній клас, який імлементовує в собі побудову дороги та оцінювання

# %%
"""
file: builder_feedforward.py
"""

class NeatForestRoadBuilderFeedForward(NeatForestRoadBuilder):
    """
    A class that uses NEAT to build a road through a forest.
    """
    def _build_path(self, net: neat.nn.FeedForwardNetwork):
        """
        'net' instance builds a road through the forest.
        """
        path = [(0, 0), (3, 3)]

        for _ in range(1, self.road_smoothness):
            if self.distance(path[-1], (self.screen_width, self.screen_height)) < 30:
                break

            delta_dest = (
                (self.screen_width - path[-1][0]) / 1,
                (self.screen_height - path[-1][1]) / 1
            )

            current_pos = (
                path[-1][0] / 1,
                path[-1][1] / 1
            )

            nearest = self.nearest_organism_cached(path[-1], self.forest_organisms, 5)
            nearest = filter(lambda x: self.distance(path[-1], x[0].center) < 30, nearest)

            delta_nearest = []
            for point in nearest:
                delta_nearest.append((point[0].center[0] - path[-1][0]) / 1)
                delta_nearest.append((point[0].center[1] - path[-1][1]) / 1)

            odd_point = [current_pos[0] - 30, current_pos[1] - 30]
            inputs = list(delta_dest) + list(current_pos) + list(delta_nearest) + odd_point * int((10 - len(delta_nearest)) / 2)

            step = 8
            output = net.activate(inputs)

            output = list(map(lambda x: 2 * (x - 0.5), output))

            path.append((
                path[-1][0] + output[0] * step,
                path[-1][1] + output[1] * step
            ))

        return path

    def eval_genome(self, genome, config):
        """
        Evaluate the fitness of a genome.
        """
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        path = self._build_path(net)

        fitness = 0

        for point in path:
            if not self.is_valid(point):
                continue

            nearest = self.nearest_organism_cached(point, self.forest_organisms, 5)
            nearest = tuple(filter(lambda x: self.distance(point, x[0].center) < 30, nearest))

            delta_fitness = 1
            for organism in nearest:
                delta_fitness *= self.distance(point, organism[0].center)

            delta_fitness = delta_fitness ** (1.0 / max(len(nearest), 1)) * 0.033 + 1
            fitness += 30 * delta_fitness

        path_length = sum(self.distance(path[i], path[i + 1]) for i in range(len(path) - 1))
        length_prop = 1 + math.fabs(path_length - self.distance((0, 0), (self.screen_height, self.screen_width)))

        delta_dest = self.distance(path[-1], (self.screen_width, self.screen_height))
        return fitness * (1 / (1 + delta_dest * 0.1)) ** 0.8 * (1 / length_prop ** 0.8)

# %% [markdown]
# #### Давайте запустимо нашу програму
#
# Спобуємо навчити нашу мережу будувати дорогу в лісі. Встановимо розімір карти, кількість травин. Важливим параметром є кількість епох навчання, яка визначає скільки разів ми будемо навчати нашу мережу. Чим більше епох, тим краще буде результат, але навчання займе більше часу.

# %%
if __name__ == "__main__":
    forest = ForestMap(
        num_organisms = 900,
        screen_width = 600,
        screen_height = 400,
    )

    # Prepare the forest and create organisms.
    forest.generate_map()
    forest.generate_organisms()

    # Create a builder instance. Let's train it for 70 generations.
    builder = NeatForestRoadBuilderFeedForward(forest, 70)
    builder.build()

    forest.run()
# Out:
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# Warning: initial_connection = full with hidden nodes will not do direct input-output connections;
# 	if this is desired, set initial_connection = full_nodirect;
# 	if not, set initial_connection = full_direct
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#      12 # Create a builder instance. Let's train it for 70 generations.
#      13 builder = NeatForestRoadBuilderFeedForward(forest, 70)
# ---> 14 builder.build()
#      16 forest.run()
#
# Cell In[6], line 74, in NeatForestRoadBuilder.build(self)
#      70 def build(self):
#      71     """
#      72     Build a road through the forest.
#      73     """
# ---> 74     self.winner = self._find_winner() if self.winner is None else self.winner
#      75     net = neat.nn.FeedForwardNetwork.create(self.winner, self.config)
#      77     self.forest_map.road = self._build_path(net)
#
# Cell In[6], line 67, in NeatForestRoadBuilder._find_winner(self)
#      65 def _find_winner(self):
#      66     pop = neat.Population(self.config)
# ---> 67     winner = pop.run(self.eval_genomes, self.num_generations)
#      68     return winner
#
# File c:\Users\sasha\AppData\Local\Programs\Python\Python310\lib\site-packages\neat\population.py:89, in Population.run(self, fitness_function, n)
#      86 self.reporters.start_generation(self.generation)
#      88 # Evaluate all genomes using the user-provided function.
# ---> 89 fitness_function(list(iteritems(self.population)), self.config)
#      91 # Gather and report statistics.
#      92 best = None
#
# Cell In[6], line 63, in NeatForestRoadBuilder.eval_genomes(self, genomes, config)
#      59 """
#      60 Evaluate the fitness of a list of genomes.
#      61 """
#      62 for _, genome in genomes:
# ---> 63     genome.fitness = self.eval_genome(genome, config)
#
# Cell In[7], line 57, in NeatForestRoadBuilderFeedForward.eval_genome(self, genome, config)
#      53 """
#      54 Evaluate the fitness of a genome.
#      55 """
#      56 net = neat.nn.FeedForwardNetwork.create(genome, config)
# ---> 57 path = self._build_path(net)
#      59 fitness = 0
#      61 for point in path:
#
# Cell In[7], line 29, in NeatForestRoadBuilderFeedForward._build_path(self, net)
#      19 delta_dest = (
#      20     (self.screen_width - path[-1][0]) / 1,
#      21     (self.screen_height - path[-1][1]) / 1
#      22 )
#      24 current_pos = (
#      25     path[-1][0] / 1,
#      26     path[-1][1] / 1
#      27 )
# ---> 29 nearest = self.nearest_organism_cached(path[-1], self.forest_organisms, 5)
#      30 nearest = filter(lambda x: self.distance(path[-1], x[0].center) < 30, nearest)
#      32 delta_nearest = []
#
# Cell In[6], line 40, in NeatForestRoadBuilder.nearest_organism_cached(point, organisms, n_first)
#      34 @staticmethod
#      35 @cache
#      36 def nearest_organism_cached(point, organisms, n_first=5):
#      37     """
#      38     Find the nearest organism to a point.
#      39     """
# ---> 40     return sorted(organisms, key=lambda x: __class__.distance(x[0].center, point))[:n_first]
#
# Cell In[6], line 40, in NeatForestRoadBuilder.nearest_organism_cached.<locals>.<lambda>(x)
#      34 @staticmethod
#      35 @cache
#      36 def nearest_organism_cached(point, organisms, n_first=5):
#      37     """
#      38     Find the nearest organism to a point.
#      39     """
# ---> 40     return sorted(organisms, key=lambda x: __class__.distance(x[0].center, point))[:n_first]
#
# KeyboardInterrupt:
